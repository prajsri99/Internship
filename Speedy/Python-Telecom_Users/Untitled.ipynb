# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("telecom_users.csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7010-BRBUU    Male              0     Yes        Yes      72          Yes
# 1  9688-YGXVR  Female              0      No         No      44          Yes
# 2  9286-DOJGF  Female              1     Yes         No      38          Yes
# 3  6994-KERXL    Male              0      No         No       4          Yes
# 4  2181-UAESM    Male              0      No         No       2          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0           Yes              No  No internet service  ...
# 1            No     Fiber optic                   No  ...
# 2           Yes     Fiber optic                   No  ...
# 3            No             DSL                   No  ...
# 4            No             DSL                  Yes  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7010-BRBUU    Male              0     Yes        Yes      72
# 1     9688-YGXVR  Female              0      No         No      44
# 2     9286-DOJGF  Female              1     Yes         No      38
# 3     6994-KERXL    Male              0      No         No       4
# 4     2181-UAESM    Male              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 6045  0684-AOSIH    Male              0     Yes         No       1
# 6046  5982-PSMKW  Female              0     Yes        Yes      23
# 6047  8044-BGWPI    Male              0     Yes        Yes      12
# 6048  7450-NWRTR    Male              1      No         No      12
# 6049  4795-UXVCJ    Male              0      No         No      26
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# ...

# %%
data.isna()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 6045       False   False          False    False       False   False
# 6046       False   False          False    False       False   False
# 6047       False   False          False    False       False   False
# 6048       False   False          False    False       False   False
# 6049       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
data_male_subscribers = data[data['gender']=='Male']

# %%
data_non_senior = data_male_subscribers[data_male_subscribers['SeniorCitizen']==0]

# %%
data_non_senior.head()
# Out:
#     customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7010-BRBUU   Male              0     Yes        Yes      72          Yes
# 3   6994-KERXL   Male              0      No         No       4          Yes
# 4   2181-UAESM   Male              0      No         No       2          Yes
# 8   8898-KASCD   Male              0      No         No      39           No
# 10  4578-PHJYZ   Male              0     Yes        Yes      52          Yes
#
#        MultipleLines InternetService       OnlineSecurity  ...  \
# 0                Yes              No  No internet service  ...
# 3                 No             DSL                   No  ...
# 4                 No             DSL                  Yes  ...
# 8   No phone service             DSL                   No  ...
# 10                No             DSL                   No  ...
#
#        DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
data_filtered_subscribers = data_non_senior[
    (data_non_senior['PhoneService']=='Yes') &
    (data_non_senior['InternetService']!='No') &
    (data_non_senior['DeviceProtection']=='Yes') &
    (data_non_senior['StreamingTV']=='Yes') &
    (data_non_senior['PaperlessBilling']=='Yes')
]
data_filtered_subscribers
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 10    4578-PHJYZ   Male              0     Yes        Yes      52
# 15    1784-EZDKJ   Male              0     Yes         No      51
# 21    4683-WYDOU   Male              0     Yes         No      62
# 38    4578-PHJYZ   Male              0     Yes        Yes      52
# 41    5193-QLVZB   Male              0      No         No      63
# ...          ...    ...            ...     ...        ...     ...
# 6004  2612-PHGOX   Male              0     Yes         No      64
# 6011  2834-JRTUA   Male              0      No         No      71
# 6013  8543-MSDMF   Male              0      No         No       3
# 6023  4660-IRIBM   Male              0     Yes        Yes      18
# 6043  6408-WHTEF   Male              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 10            Yes            No             DSL             No  ...
# ...

# %%
total_male_subscribers = len(data_filtered_subscribers)

# %%
print("Total Male Subscribers(Who are not senior citizens) with the specified services:",total_male_subscribers)
# Out:
# Total Male Subscribers(Who are not senior citizens) with the specified services: 318

# %%
data_female_subscribers = data[data['gender']=='Female']

# %%
data_female_non_senior = data_female_subscribers[data_female_subscribers['SeniorCitizen']==0]

# %%
data_female_non_senior.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1   9688-YGXVR  Female              0      No         No      44          Yes
# 5   4312-GVYNH  Female              0     Yes         No      70           No
# 6   2495-KZNFB  Female              0      No         No      33          Yes
# 7   4367-NHWMM  Female              0      No         No       1           No
# 11  2091-MJTFX  Female              0     Yes        Yes      30           No
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 1                 No     Fiber optic             No  ...              Yes
# 5   No phone service             DSL            Yes  ...              Yes
# 6                Yes     Fiber optic            Yes  ...               No
# 7   No phone service             DSL             No  ...               No
# 11  No phone service             DSL             No  ...               No
#
# ...

# %%
data_female_filtered_subscribers = data_female_non_senior[
    (data_female_non_senior['PhoneService']=='Yes') &
    (data_female_non_senior['InternetService']!='No') &
    (data_female_non_senior['DeviceProtection']=='Yes') &
    (data_female_non_senior['StreamingTV']=='Yes') &
    (data_female_non_senior['PaperlessBilling']=='Yes')
]
data_female_filtered_subscribers
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     9688-YGXVR  Female              0      No         No      44
# 14    2731-GJRDG  Female              0      No         No      32
# 29    9688-YGXVR  Female              0      No         No      44
# 43    4657-FWVFY  Female              0     Yes        Yes      40
# 70    8071-SBTRN  Female              0      No         No      70
# ...          ...     ...            ...     ...        ...     ...
# 5980  8823-RLPWL  Female              0     Yes         No      72
# 5993  9481-SFCQY  Female              0      No        Yes      14
# 5999  3886-CERTZ  Female              0     Yes         No      72
# 6040  6386-SZZKH  Female              0     Yes        Yes      49
# 6046  5982-PSMKW  Female              0     Yes        Yes      23
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes            No     Fiber optic             No  ...
# ...

# %%
total_female_subscribers = len(data_female_filtered_subscribers)

# %%
print("Total female Subscribers(Who are not senior citizens) with the specified services:",total_female_subscribers)
# Out:
# Total female Subscribers(Who are not senior citizens) with the specified services: 334
